# %%
import pandas as pd
import plotly.plotly as py
import plotly.graph_objs as go

# %%
df = pd.read_excel(r'C:\Users\belewaut\Downloads\20210829_coolblue_raw_data_Telefonie.xlsx')

# %%
df['price'] = df['price'].str.replace(r'-','')
df['price'] = df['price'].str.rstrip(',')
df['price'] = df['price'].str.rstrip(' ')
df['price'].head(10)
# Out:
# 0     1.799
# 1     1.049
# 2       489
# 3    863,99
# 4       449
# 5    503,99
# 6    955,92
# 7       779
# 8    798,93
# 9       439
# Name: price, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552 entries, 0 to 2551
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_description  2552 non-null   object
#  1   price                2552 non-null   object
#  2   rating               2552 non-null   float64
#  3   amount_reviews       2552 non-null   object
#  4   product_category     2552 non-null   object
#  5   product_class        2552 non-null   object
#  6   date_of_scrape       2552 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 139.7+ KB

# %%
df["amount_reviews"] = df['amount_reviews'].str.replace(r' reviews','')
df["product_category"] = df["product_category"].str.replace(r'mobiele-telefoons','smartphones')
df["rating"] = pd.to_numeric(df['rating'], errors = 'coerce')

# %%
df["amount_reviews"] = df['amount_reviews'].str.replace(r'1 review','1')
df["amount_reviews"] = df['amount_reviews'].fillna(0.0).astype(int)

# %%
df.head(20)
# Out:
#                                   product_description     price  rating  \
# 0              Samsung Galaxy Z Fold 3 256GB Zwart 5G     1.799     5.0
# 1              Samsung Galaxy Z Flip 3 128GB Zwart 5G     1.049     0.0
# 2                Samsung Galaxy S20 FE 128GB Blauw 4G       489     4.5
# 3   Apple iPhone 12 128GB Zwart + Apple Usb C Opla...    863,99     4.5
# 4                  Samsung Galaxy A52s 128GB Groen 5G       449     0.0
# 5   Apple iPhone SE 64GB Zwart + Apple Usb C Oplad...    503,99     4.5
# 6   Apple iPhone 12 128GB Zwart + Accessoirepakket...    955,92     0.0
# 7                   Samsung Galaxy S21 128GB Grijs 5G       779     4.5
# 8     Apple iPhone 11 128 GB Zwart + Accessoirepakket    798,93     0.0
# 9                      Samsung Galaxy A72 128GB Zwart       439     4.5
# 10  Apple iPhone SE 128GB Zwart + Apple Usb C Opla...    553,99     4.5
# 11  Apple iPhone 12 mini 128GB Zwart + Apple Usb C...    773,99     4.5
# 12  Samsung Galaxy S21 128GB Grijs 5G + Samsung Sn...    803,99     4.5
# 13  Samsung Galaxy S21 Ultra 256GB Zwart 5G + Sams...  1.193,99     4.5
# 14                       Apple iPhone SE 128 GB Zwart       529     4.5
# 15                        Apple iPhone 12 128GB Zwart       839     4.5
# 16  Apple iPhone 12 64GB Zwart + Apple Usb C Oplad...    833,99     4.5
# 17     Apple iPhone 12 128GB Zwart + Accessoirepakket    915,93     0.0
# 18  Apple iPhone 11 64 GB Zwart + Otterbox Clearly...    703,99     4.5
# 19           Samsung Galaxy S21 Ultra 256 GB Zwart 5G     1.169     4.5
#
#     amount_reviews product_category product_class          date_of_scrape
# 0                2      smartphones     telefonie 2021-08-29 19:21:43.493
# 1                0      smartphones     telefonie 2021-08-29 19:21:43.493
# 2              331      smartphones     telefonie 2021-08-29 19:21:43.493
# 3              408      smartphones     telefonie 2021-08-29 19:21:43.493
# 4                0      smartphones     telefonie 2021-08-29 19:21:43.493
# 5              999      smartphones     telefonie 2021-08-29 19:21:43.493
# 6                0      smartphones     telefonie 2021-08-29 19:21:43.493
# 7              112      smartphones     telefonie 2021-08-29 19:21:43.493
# 8                0      smartphones     telefonie 2021-08-29 19:21:43.493
# 9               96      smartphones     telefonie 2021-08-29 19:21:43.493
# 10             999      smartphones     telefonie 2021-08-29 19:21:43.493
# 11             352      smartphones     telefonie 2021-08-29 19:21:43.493
# 12             112      smartphones     telefonie 2021-08-29 19:21:43.493
# 13              90      smartphones     telefonie 2021-08-29 19:21:43.493
# 14             999      smartphones     telefonie 2021-08-29 19:21:43.493
# 15             408      smartphones     telefonie 2021-08-29 19:21:43.493
# 16             408      smartphones     telefonie 2021-08-29 19:21:43.493
# 17               0      smartphones     telefonie 2021-08-29 19:21:43.493
# 18            1391      smartphones     telefonie 2021-08-29 19:21:43.493
# 19              90      smartphones     telefonie 2021-08-29 19:21:43.493

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552 entries, 0 to 2551
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_description  2552 non-null   object
#  1   price                2552 non-null   object
#  2   rating               2552 non-null   float64
#  3   amount_reviews       2552 non-null   int32
#  4   product_category     2552 non-null   object
#  5   product_class        2552 non-null   object
#  6   date_of_scrape       2552 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int32(1), object(4)
# memory usage: 129.7+ KB

# %%
df.head()
# Out:
#                                  product_description   price  rating  \
# 0             Samsung Galaxy Z Fold 3 256GB Zwart 5G   1.799     5.0
# 1             Samsung Galaxy Z Flip 3 128GB Zwart 5G   1.049     0.0
# 2               Samsung Galaxy S20 FE 128GB Blauw 4G     489     4.5
# 3  Apple iPhone 12 128GB Zwart + Apple Usb C Opla...  863,99     4.5
# 4                 Samsung Galaxy A52s 128GB Groen 5G     449     0.0
#
#    amount_reviews product_category product_class          date_of_scrape
# 0               2      smartphones     telefonie 2021-08-29 19:21:43.493
# 1               0      smartphones     telefonie 2021-08-29 19:21:43.493
# 2             331      smartphones     telefonie 2021-08-29 19:21:43.493
# 3             408      smartphones     telefonie 2021-08-29 19:21:43.493
# 4               0      smartphones     telefonie 2021-08-29 19:21:43.493

# %%
df["price"] = df['price'].str.replace(r'.','')
df["price"] = df['price'].str.replace(r',','.')
df["price"] = pd.to_numeric(df['price'], errors = 'raise')

# %%
df["date_of_scrape"] = df['date_of_scrape'].dt.strftime("%d/%m/%y")

# %%
df["product_category"].unique()
# Out:
# array(['smartphones', 'vaste-telefoons', 'telefoonhoesjes',
#        'screenprotectors/screenprotectors-voor-smartphones',
#        'kabels-adapters-laders', 'horloges',
#        'mobiele-telefoon-accessoires'], dtype=object)

# %%
df.drop(columns=["product_class","date_of_scrape"])
# Out:
#                                     product_description    price  rating  \
# 0                Samsung Galaxy Z Fold 3 256GB Zwart 5G  1799.00     5.0
# 1                Samsung Galaxy Z Flip 3 128GB Zwart 5G  1049.00     0.0
# 2                  Samsung Galaxy S20 FE 128GB Blauw 4G   489.00     4.5
# 3     Apple iPhone 12 128GB Zwart + Apple Usb C Opla...   863.99     4.5
# 4                    Samsung Galaxy A52s 128GB Groen 5G   449.00     0.0
# ...                                                 ...      ...     ...
# 2547  Belkin Autolader zonder Kabel Usb C 18W Power ...    24.99     5.0
# 2548  PanzerGlass Privacy Camslider Apple iPhone X /...    27.99     4.0
# 2549                        Samsung Galaxy Buds 2 Groen   149.00     0.0
# 2550       Azuri Wallet Xiaomi Redmi 9T Book Case Zwart    21.95     4.0
# 2551       Kenu Airbase Pro Autohouder Universeel Zwart    29.99     5.0
#
#       amount_reviews              product_category
# 0                  2                   smartphones
# 1                  0                   smartphones
# 2                331                   smartphones
# 3                408                   smartphones
# 4                  0                   smartphones
# ...              ...                           ...
# 2547               2  mobiele-telefoon-accessoires
# 2548               6  mobiele-telefoon-accessoires
# 2549               0  mobiele-telefoon-accessoires
# 2550               6  mobiele-telefoon-accessoires
# 2551              11  mobiele-telefoon-accessoires
#
# [2552 rows x 5 columns]

# %%
df_test = df['product_category']=='smartphones'

# %%
df = df[df_test]

# %%
df[['brand', 'product_description']] = df['product_description'].str.split(' ', 1, expand=True)

# %%
df.tail(10)
# Out:
#                                    product_description    price  rating  \
# 430                     Galaxy Z Fold 3 256GB Groen 5G  1799.00     5.0
# 431  Galaxy S21 Ultra 128GB Zwart 5G + Samsung Snel...  1103.99     4.5
# 432                             Galaxy A72 128GB Paars   439.00     4.5
# 433                                 Smart.3 Mini Zwart   146.99     4.0
# 434                   Galaxy S21 Ultra 512GB Zilver 5G  1399.00     4.5
# 435  Galaxy Z Flip 3 128GB Crème 5G + Samsung Draad...  1058.00     0.0
# 436                                      S4 32GB Zwart   179.00     0.0
# 437  Nord 256GB Grijs 5G + OnePlus Nord Sandstone B...   444.99     4.5
# 438                         Euphoria Senioren Telefoon    62.99     4.0
# 439                     Galaxy Z Fold 3 512GB Zwart 5G  1899.00     5.0
#
#      amount_reviews product_category product_class date_of_scrape    brand
# 430               2      smartphones     telefonie       29/08/21  Samsung
# 431              90      smartphones     telefonie       29/08/21  Samsung
# 432              96      smartphones     telefonie       29/08/21  Samsung
# 433               7      smartphones     telefonie       29/08/21  Emporia
# 434              90      smartphones     telefonie       29/08/21  Samsung
# 435               0      smartphones     telefonie       29/08/21  Samsung
# 436               0      smartphones     telefonie       29/08/21  Emporia
# 437            1006      smartphones     telefonie       29/08/21  OnePlus
# 438              75      smartphones     telefonie       29/08/21  Emporia
# 439               2      smartphones     telefonie       29/08/21  Samsung

# %%
df['brand'].unique()
# Out:
# array(['Samsung', 'Apple', 'OnePlus', 'MagSafe', 'OPPO', 'Sony',
#        'Motorola', 'Xiaomi', 'Nokia', 'Starterspakket', 'Cat', 'CAT',
#        'Fysic', 'CrossCall', 'Emporia'], dtype=object)
